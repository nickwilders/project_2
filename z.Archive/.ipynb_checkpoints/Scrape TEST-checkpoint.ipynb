# %%
import requests as re
from bs4 import BeautifulSoup

batb = re.get('https://www.imdb.com/title/tt2771200/?ref_=adv_li_tt')

batb_soup = BeautifulSoup(batb.text, 'html5lib')

# store the addresses here:
addr = []

states = {}

# for row in rows

# %%
batb_soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#"><head>
#
#         <meta charset="utf-8"/>
#         <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#
#     <meta content="app-id=342792525, app-argument=imdb:///title/tt2771200?src=mdot" name="apple-itunes-app"/>
#
#
#
#         <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
#
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
#   <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
#         <title>Beauty and the Beast (2017) - IMDb</title>
#   <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
# ...

# %%
# LIST OF STARS

stars = batb_soup.find('h4', text='Stars:')
stars = stars.find_parent('div')
stars = str(stars).split('</h4>')
stars = stars[1].split('<span')[0]
stars = stars.split('</div>')[0].strip()
stars = stars.split('">')
stars_list = []
for i, actor in enumerate(stars):
    actor = stars[i].split('</a>')[0]
    stars_list.append(actor)

stars_list.remove(stars_list[0])

stars_list
# Out:
# ['Emma Watson', 'Dan Stevens', 'Luke Evans']

# %%
# DIRECTOR

director = batb_soup.find('h4', text='Director:')
director = director.find_parent('div')
director = str(director).split('</h4>')
director = director[1].split('<span')[0]
director = director.split('</div>')[0].strip()
director = director.split('">')
director = director[1].split('</a>')[0]

director
# Out:
# 'Bill Condon'

# %%
# RELEASE DATE 
release = batb_soup.find('h4', text='Release Date:')
release = release.find_parent('div')
release = str(release).split('</h4>')
release = release[1].split('<span')[0]
release = release.split('</div>')[0].strip()
print(release)
# Out:
# 17 March 2017 (USA)

# %%
# FILMING LOCATION
film_location = batb_soup.find('h4', text='Filming Locations:')
film_location = film_location.find_parent('div')
film_location = str(film_location).split('</h4>')
film_location = film_location[1].split('<span')[0]
film_location = film_location.split('</div>')[0].strip()
film_location = film_location.split('">')
film_location = film_location[1].split('</a>')[0]
print(film_location)
# Out:
# London, England, UK

# %%
# ALSO KNOWN AS
aka = batb_soup.find('h4', text='Also Known As:')
aka = aka.find_parent('div')
aka = str(aka).split('</h4>')
aka = aka[1].split('<span')[0]
aka = aka.split('</div>')[0].strip()
print(aka)
# Out:
# Beauty and the Beast

# %%
# useful info
genre= batb_soup.find_all('script', type="application/ld+json")

# %%
# OSCAR NOMINATION - if this does not return a value, page does not have the Awards blurb
# this number represents number of Oscar nominations
awards = batb_soup
awards = batb_soup.find('span', class_='awards-blurb')
awards = str(awards).split('Nominated for')
awards = awards[1].split('\n')
awards = awards[1].strip()
awards
# Out:
# '2'

# %%
# GENRE
genre = batb_soup.find_all('script', type="application/ld+json")

genre = str(genre).split("genre")
genre = genre[1].split("  ]")
genre = genre[0].split("\n")
genre.remove(genre[0])
genre.remove(genre[4])
genre_list = []
for entry in genre:
    entry = entry.strip()
    entry = entry.replace('\"', '')
    entry = entry.replace(',', '')
    print(entry)
    genre_list.append(entry)

genre_list
# Out:
# Family
# Fantasy
# Musical
# Romance
# ['Family', 'Fantasy', 'Musical', 'Romance']

# %%
# BUDGET
budget_value = batb_soup
budget_value = batb_soup.find('h4', text='Budget:')
budget_value = budget_value.find_parent('div')
budget_value = str(budget_value).split('</h4>')
budget_value = budget_value[1].split('<span')[0]
print(budget_value)
# Out:
# $160,000,000

# %%
# GROSS USA
grossUSA = batb_soup.find('h4', text='Gross USA:')
grossUSA = grossUSA.find_parent('div')
grossUSA = str(grossUSA).split('</h4>')
grossUSA = grossUSA[1].split('<span')[0]
grossUSA = grossUSA.split('</div>')[0].strip()
print(grossUSA)
# Out:
# $504,481,165

# %%
# WORLDWIDE GROSS 
worldwide = batb_soup.find('h4', text='Cumulative Worldwide Gross:')
worldwide = worldwide.find_parent('div')
worldwide = str(worldwide).split('</h4>')
worldwide = worldwide[1].split('<span')[0]
worldwide = worldwide.split('</div>')[0].strip()
print(worldwide)
# Out:
# $1,264,064,386

# %%
# Find MPAA rating
rating_value = batb_soup
rating = batb_soup.find('div', class_='subtext').text
rating = rating.split('\n')
rating = rating[1].strip()
rating
# Out:
# 'PG'

# %%
# test to try to get text after the h4 frame
soup = BeautifulSoup(batb.text, 'html.parser')
test = batb_soup.find_all('h4', class_='inline')[10]

header.contents[-1].strip()
# Out:
# 'Director:'

# %%
import re

def get_movie_value(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    
    obj = soup.find(text=re.compile(field_name))
    
    if not obj: 
        return None
    
    # this works for most of the values
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text
    else:
        return None

# %%
# Find the first listed genre 
first_genre = get_movie_value(batb_soup, 'Genres')
first_genre = first_genre.strip()
first_genre
# Out:
# 'Family'

# %%
# Find MPAA rating
rating_value = batb_soup
rating = batb_soup.find('div', class_='subtext').text
rating = rating.split('\n')
rating = rating[1].strip()
rating
# Out:
# 'PG'

# %%
# Find Release date
rating_value = batb_soup
rating = batb_soup.find('div', class_='subtext').text
rating.strip()
#rating = rating.split('\n')
#rating = rating[1].strip()
#rating
# Out:
# 'PG\n    |                    \n                        2h 9min\n                    \n    |\nFamily, \nFantasy, \nMusical\n    |\n17 March 2017 (USA)'

# %%
# Find run time
runtime = batb_soup.find('time', datetime='PT129M').text
runtime = runtime.replace('\n', '')
runtime = runtime.strip()
runtime_hours = runtime[0].split()
runtime
# Out:
# ['2']

# %%
# Find the first listed genre 
runtime = get_movie_value(batb_soup, 'Runtime')
runtime = runtime.strip()
runtime = runtime.split()[0]

def convert(minutes): 
    minutes = seconds % (24 * 3600) 
    hour = seconds // 3600
    seconds %= 3600
    minutes = seconds // 60
    seconds %= 60
      
    return "%d:%02d:%02d" % (hour, minutes, seconds) 
      
# Driver program 
n = 12345
print(convert(n))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-10187b081311> in <module>
#      15 # Driver program
#      16 n = 12345
# ---> 17 print(convert(n))
#
# <ipython-input-103-10187b081311> in convert(seconds)
#      11     seconds %= 60
#      12
# ---> 13     return "%d:%02d:%02d" % (minutes, seconds)
#      14
#      15 # Driver program
#
# TypeError: not enough arguments for format string

# %%
# Out:
# datetime.timedelta(seconds=21600)
