# %%
import pandas as pd

# %%
df = pd.read_csv('oscars.csv')

# %%
df.to_csv('oscars.csv')

# %%
df[df.year_film == 2019][df.winner==True]
# Out:
# <ipython-input-37-fe9a29b4fc6d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.year_film == 2019][df.winner==True]
#        year_film  year_ceremony  ceremony                          category  \
# 10270       2019           2020        92           ACTOR IN A LEADING ROLE
# 10276       2019           2020        92        ACTOR IN A SUPPORTING ROLE
# 10281       2019           2020        92         ACTRESS IN A LEADING ROLE
# 10283       2019           2020        92      ACTRESS IN A SUPPORTING ROLE
# 10291       2019           2020        92             ANIMATED FEATURE FILM
# 10295       2019           2020        92                    CINEMATOGRAPHY
# 10300       2019           2020        92                    COSTUME DESIGN
# 10306       2019           2020        92                         DIRECTING
# 10307       2019           2020        92             DOCUMENTARY (Feature)
# ...

# %%
df[df.category == 'DOCUMENTARY (Feature)'][df.winner==True].tail(50)
# Out:
# <ipython-input-49-f6e09895cfca>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.category == 'DOCUMENTARY (Feature)'][df.winner==True].tail(50)
#        year_film  year_ceremony  ceremony               category  \
# 4921        1971           1972        44  DOCUMENTARY (Feature)
# 5027        1972           1973        45  DOCUMENTARY (Feature)
# 5130        1973           1974        46  DOCUMENTARY (Feature)
# 5234        1974           1975        47  DOCUMENTARY (Feature)
# 5341        1975           1976        48  DOCUMENTARY (Feature)
# 5445        1976           1977        49  DOCUMENTARY (Feature)
# 5553        1977           1978        50  DOCUMENTARY (Feature)
# 5661        1978           1979        51  DOCUMENTARY (Feature)
# 5764        1979           1980        52  DOCUMENTARY (Feature)
# 5877        1980           1981        53  DOCUMENTARY (Feature)
# 5977        1981           1982        54  DOCUMENTARY (Feature)
# ...

# %%
df.category.unique()
# Out:
# array(['ACTOR', 'ACTRESS', 'ART DIRECTION', 'CINEMATOGRAPHY',
#        'DIRECTING (Comedy Picture)', 'DIRECTING (Dramatic Picture)',
#        'ENGINEERING EFFECTS', 'OUTSTANDING PICTURE',
#        'UNIQUE AND ARTISTIC PICTURE', 'WRITING (Adaptation)',
#        'WRITING (Original Story)', 'WRITING (Title Writing)',
#        'SPECIAL AWARD', 'DIRECTING', 'WRITING', 'OUTSTANDING PRODUCTION',
#        'SOUND RECORDING', 'SHORT SUBJECT (Cartoon)',
#        'SHORT SUBJECT (Comedy)', 'SHORT SUBJECT (Novelty)',
#        'ASSISTANT DIRECTOR', 'FILM EDITING', 'MUSIC (Scoring)',
#        'MUSIC (Song)', 'DANCE DIRECTION', 'WRITING (Screenplay)',
#        'ACTOR IN A SUPPORTING ROLE', 'ACTRESS IN A SUPPORTING ROLE',
#        'SHORT SUBJECT (Color)', 'SHORT SUBJECT (One-reel)',
#        'SHORT SUBJECT (Two-reel)', 'IRVING G. THALBERG MEMORIAL AWARD',
#        'MUSIC (Original Score)', 'CINEMATOGRAPHY (Black-and-White)',
#        'CINEMATOGRAPHY (Color)', 'SPECIAL EFFECTS',
# ...

# %%
new_column = df.category.replace('ACTOR IN A LEADING ROLE', 'ACTOR')
new_column = new_column.replace('ACTRESS IN A LEADING ROLE', 'ACTRESS')
new_column = new_column.replace('ACTRESS IN A SUPPORTING ROLE', 'SUPPORTING ACTRESS')
new_column = new_column.replace('ACTOR IN A SUPPORTING ROLE', 'SUPPORTING ACTOR')

music_list = ['MUSIC (Original Song)', 
            'MUSIC (Original Score)',
            'MUSIC (Music Score of a Dramatic Picture)',
            'MUSIC (Scoring of a Musical Picture)',
            'MUSIC (Music Score of a Dramatic or Comedy Picture)',
            'MUSIC (Music Score of a Dramatic or Comedy Picture)',
            'MUSIC (Music Score--substantially original)',
            'MUSIC (Scoring of Music--adaptation or treatment)',
            'MUSIC (Original Music Score)',
            'MUSIC (Original Music Score)',
            'MUSIC (Original Score--for a motion picture [not a musical])',
            'MUSIC (Score of a Musical Picture--original or adaptation)',
            'MUSIC (Song--Original for the Picture)',
            'MUSIC (Original Song Score)',
            'MUSIC (Original Dramatic Score)',
            'MUSIC (Scoring: Adaptation and Original Song Score)',
            'MUSIC (Scoring: Original Song Score and Adaptation -or- Scoring: Adaptation)',
            'MUSIC (Original Song Score and Its Adaptation or Adaptation Score)'
            'MUSIC (Adaptation Score)',
            'MUSIC (Original Song Score and Its Adaptation -or- Adaptation Score)',
            'MUSIC (Original Song Score or Adaptation Score)',
            'MUSIC (Original Musical or Comedy Score)',
            'MUSIC (Original Song Score and Its Adaptation or Adaptation Score)',
            'MUSIC (Scoring)',
            'MUSIC (Song)']

directing_list = ['DIRECTING (Comedy Picture)',
            'DIRECTING (Dramatic Picture)']



picture_list = ['OUTSTANDING PICTURE', 
                'BEST MOTION PICTURE',
                'OUTSTANDING MOTION PICTURE']

for title in music_list:
    new_column = new_column.replace(title, 'MUSIC')
    
for title in directing_list:
    new_column = new_column.replace(title, 'DIRECTING')
    
for title in picture_list:
    new_column = new_column.replace(title, 'BEST PICTURE')


        

df.category = new_column

# %%
category_list = ['ACTOR', 'ACTRESS', 'SUPPORTING ACTOR', 'SUPPORTING ACTRESS', 'BEST PICTURE',
                 'ANIMATED FEATURE FILM', 'MUSIC', 'DIRECTING']

specific_award_df = df[df.category.isin(category_list)]

# %%
test_df
# Out:
#        year_film  year_ceremony  ceremony               category  \
# 0           1927           1928         1                  ACTOR
# 1           1927           1928         1                  ACTOR
# 2           1927           1928         1                ACTRESS
# 3           1927           1928         1                ACTRESS
# 4           1927           1928         1                ACTRESS
# 11          1927           1928         1              DIRECTING
# 12          1927           1928         1              DIRECTING
# 13          1927           1928         1              DIRECTING
# 14          1927           1928         1              DIRECTING
# 15          1927           1928         1              DIRECTING
# 19          1927           1928         1           BEST PICTURE
# 20          1927           1928         1           BEST PICTURE
# 21          1927           1928         1           BEST PICTURE
# ...

# %%
pd.set_option('display.max_rows', None)
specific_award_df.name[specific_award_df.category=='MUSIC'].value_counts()
# Out:
# John Williams                                                                                                                                                                        44
# Alfred Newman                                                                                                                                                                        34
# Victor Young                                                                                                                                                                         19
# Max Steiner                                                                                                                                                                          16
# Jerry Goldsmith                                                                                                                                                                      16
# ...

# %%
test_df = specific_award_df

for i,name in enumerate(test_df.name):
    print(test_df.name[i])
    
    '''test_df.name[i].replace("Music and Lyrics", '')
    test_df.name[i].replace("Music and Lyric", '')
    test_df.name[i].replace("Music by", '')
    test_df.name[i].replace("Lyrics by", '')
    test_df.name[i].replace("Lyric by", '')
    test_df.name[i].replace("by", '')
    test_df.name[i].replace("Music and Lyrics", '')
    test_df.name[i].replace(" and", ',')
    test_df.name[i].replace(";", ',')
    '''
    
specific_award_
# Out:
# Richard Barthelmess
# Emil Jannings
# Louise Dresser
# Janet Gaynor
# Gloria Swanson
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-0255ca8ca776> in <module>
#       2
#       3 for i,name in enumerate(test_df.name):
# ----> 4     print(test_df.name[i])
#       5
#       6     '''test_df.name[i].replace("Music and Lyrics", '')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# ...

# %%
specific_award_df.to_csv('filtered_oscars.csv')

# %%
import pandas as pd

df = pd.read_csv('oscars.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0  year_film  year_ceremony  ceremony             category  \
# 0            0       1927           1928         1                ACTOR
# 1            1       1927           1928         1                ACTOR
# 2            2       1927           1928         1              ACTRESS
# 3            3       1927           1928         1              ACTRESS
# 4            4       1927           1928         1              ACTRESS
# 5            5       1927           1928         1        ART DIRECTION
# 6            6       1927           1928         1        ART DIRECTION
# 7            7       1927           1928         1        ART DIRECTION
# 8            8       1927           1928         1       CINEMATOGRAPHY
# 9            9       1927           1928         1       CINEMATOGRAPHY
# 10          10       1927           1928         1       CINEMATOGRAPHY
# 11          11       1927           1928         1            DIRECTING
# ...

# %%
df

test_df = df[df.duplicated(['year_film', 'category'], keep=False)]

# %%
test_df = df[df.winner == True]

duplicate = test_df.duplicated(subset=['year_ceremony', 'category'])

# %%
df
# Out:
#        Unnamed: 0  year_film  year_ceremony  ceremony  \
# 0               0       1927           1928         1
# 1               1       1927           1928         1
# 2               2       1927           1928         1
# 3               3       1927           1928         1
# 4               4       1927           1928         1
# ...           ...        ...            ...       ...
# 10390       10390       2019           2020        92
# 10391       10391       2019           2020        92
# 10392       10392       2019           2020        92
# 10393       10393       2019           2020        92
# 10394       10394       2019           2020        92
#
#                                category  \
# 0                                 ACTOR
# 1                                 ACTOR
# 2                               ACTRESS
# 3                               ACTRESS
# 4                               ACTRESS
# ...                                 ...
# ...

# %%
columns = ['Unnamed: 0', 'year_film', 'year_ceremony', 'ceremony', 'category', 'name', 'film', 'winner', 'duplicate']

# %%
test_df.loc[:,'duplicate'] = duplicate
# Out:
# /Users/nick/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/nick/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
barbra = df['name'].str.contains('Barbra Streisand')
df.barbra = barbra
df[barbra==True]
# Out:
#       Unnamed: 0  year_film  year_ceremony  ceremony      category  \
# 4573        4573       1968           1969        41       ACTRESS
# 5101        5101       1973           1974        46       ACTRESS
# 5476        5476       1976           1977        49         MUSIC
# 7073        7073       1991           1992        64  BEST PICTURE
# 7628        7628       1996           1997        69         MUSIC
#
#                                                    name  \
# 4573                                   Barbra Streisand
# 5101                                   Barbra Streisand
# 5476  Music by Barbra Streisand; Lyrics by Paul Will...
# 7073      Barbra Streisand and Andrew Karsch, Producers
# 7628  Music and Lyric by Barbra Streisand, Marvin Ha...
#
#                           film  winner duplicate  barbra
# 4573                Funny Girl    True      True   False
# 5101           The Way We Were   False       NaN   False
# ...

# %%
duplicate = winners[winners.duplicated(['year_ceremony', 'category'])]

# %%
len(duplicate)
# Out:
# 249

# %%
no_honorary = duplicate[duplicate.category != 'HONORARY AWARD']

# %%
no_honorary[no_honorary.category == 'ACTOR']
# Out:
#      Unnamed: 0  year_film  year_ceremony  ceremony category           name  \
# 161         161       1931           1932         5    ACTOR  Fredric March
#
#                         film  winner duplicate  barbra
# 161  Dr. Jekyll and Mr. Hyde    True      True   False

# %%
winners = df[df.winner==True]

# %%
df[df.film == 'A Star Is Born'].head(50)
# Out:
#        Unnamed: 0  year_film  year_ceremony  ceremony  \
# 523           523       1937           1938        10
# 534           534       1937           1938        10
# 558           558       1937           1938        10
# 573           573       1937           1938        10
# 607           607       1937           1938        10
# 634           634       1937           1938        10
# 639           639       1937           1938        10
# 2888         2888       1954           1955        27
# 2896         2896       1954           1955        27
# 2913         2913       1954           1955        27
# 2933         2933       1954           1955        27
# 2958         2958       1954           1955        27
# 2963         2963       1954           1955        27
# 5434         5434       1976           1977        49
# 5472         5472       1976           1977        49
# 5476         5476       1976           1977        49
# ...
