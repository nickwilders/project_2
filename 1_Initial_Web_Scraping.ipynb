# %% [markdown]
# # Part 1 - Web Scraping

# %% [markdown]
# This notebook holds the function to scrape details from 10,000 movies links listed as "Musical" on IMDB.

# %% [markdown]
# ## For the first part of my project, I built a function to scrape a web page featuring 10,000 movie links for the data contained within the page (see README.md for more info)

# %%
# when we make this into a function, got to account for duplicates - if the URL has already been added, PASS.
# started at 10/1/20, 11:55pm. ended at 10/2/20, 2:21am (roughly 2.5 hrs) - 9950 movies (first 50 already done)


import requests as requests
import re
from bs4 import BeautifulSoup
import numpy as np

# Note: only including first 10k results, the last ~200 results were not adapted to or from stage 

# big_url_list refers to the list of lists that include 50 movies of a certain genre
per_50_url_list = []

for i in np.arange(0,200):
    # per_50_url refers to the the individual page displaying 50 movies, of the full list of movies per genre
    per_50_url = 'https://www.imdb.com/search/title/?title_type=movie&genres=musical&start=' + str(((i)*50)+1) + '&explore=title_type,genres&ref_=adv_nxt'
    per_50_url_list.append(per_50_url)
    
# master_url_list is list of URL's, organized by lists of 50 (len(master_url_list==199))...
# and each element in that list is a sublist with 50 entries (9950 total)
master_url_list = []

for ind_per_50_url in per_50_url_list:
    # master_url_list refers to the list of ALL URL's of ALL movies in a genre
        demi_master_url_list = scrape_urls_from_50_per_page(ind_per_50_url)
        master_url_list.append(demi_master_url_list)

# page_title_list is a list of Titles for each movie/URL 
page_title_list = []
# page_runtime_list is a list of Runtimes (in minutes) for each movie/URL 
page_runtime_list = []
# page_stars_list is a list of "Star(s):" entry for each movie/URL
page_stars_list = []
# page_directors_list is a list of "Director(s):" entry for each movie/URL
page_directors_list = []
# ...etc
page_release_list = []
page_location_list = []
page_aka_list = []
page_awards_list = []
page_genres_list = []
page_budget_list = []
page_grossUSA_list = []
page_worldwide_list = []
page_rating_list = []


# ind_master_url_list is the list of all unique URL's in this genre 
ind_master_url_list = []

# separates URL's from sublist in master_url_list to individual URL's
for fifty_list in master_url_list:
    for i, num in enumerate(fifty_list):
        ind_master_url_list.append(fifty_list[i])


# requests soup for each individual page in ind_master_url_list, and extracts all needed values
for movie_page in ind_master_url_list:
    movie = requests.get(movie_page)
    movie_soup = BeautifulSoup(movie.text, 'html5lib')
    
    # TITLE
    try:
        title = movie_soup.find_all('title')[0]
        title = str(title).split('<title>')
        title = title[1].split(' (')
        title = title[0]
        page_title_list.append(title)
    except: 
        page_title_list.append('Not found')
        
    # RUNTIME
        
    try:
        # checks if runtime reads hours only (i.e. '2h', representing 2 hours)
        if len(runtime) == 2:
            runtime_hours = runtime[0].split()
            runtime_minutes = ['0']

        # checks if runtime reads minutes only in single digits (i.e. '9min', representing 9 minutes)
        elif len(runtime) == 4:
            runtime_hours = ['0']
            runtime_minutes = runtime[0].split()

        # checks if runtime reads minutes only in double digits (i.e. '45 min', representing 45 minutes)
        elif len(runtime) == 5:
            runtime_hours = ['0']
            runtime_minutes = runtime[0:2].split()

        # checks if runtime reads hours and minutes (i.e. 2h 45min, representing 2 hours and 45 minutes)
        elif len(runtime) > 5:
            runtime_hours = runtime[0].split()
            if runtime[5] == 'm':
                runtime_minutes = runtime[3:5].split()
            else:
                runtime_minutes = runtime[3].split()
                
        # converts strings to integers and calculates total minutes for final runtime variable 
        int_hours = int(runtime_hours[0])
        int_minutes = int(runtime_minutes[0])
        total_minutes = (int_hours*60) + int_minutes
        total_minutes
        page_runtime_list.append(total_minutes)
    except:
        page_runtime_list.append('Not found')
        


    # STAR(S)
    # try/except accounts for any page with missing values for 'Star(s):'
    try:
        stars = movie_soup.find('h4', text=re.compile('Star'))
        stars = stars.find_parent('div')
        # appropriate text transformation...
        stars = str(stars).split('</h4>')
        stars = stars[1].split('<span')[0]
        stars = stars.split('</div>')[0].strip()
        stars = stars.split('">')
        stars_list = []
        # splits sublist of stars ['['a','b','c']'] into individual values ['a', 'b', 'c']
        for i, actor in enumerate(stars):
            actor = stars[i].split('</a>')[0]
            stars_list.append(actor)

        # removes irrelevant value (leading text before first Star name)
        stars_list.remove(stars_list[0])
        page_stars_list.append(stars_list)
    except:
        page_stars_list.append('Not found')

    
    # DIRECTOR(S)
    # try/except accounts for any page with missing values for 'Director(s):' (pattern continues through features)
    try:
        directors = movie_soup.find('h4', text=re.compile('Director'))
        directors = directors.find_parent('div')
        directors = str(directors).split('</h4>')
        directors = directors[1].split('<span')[0]
        directors = directors.split('</div>')[0].strip()
        directors = directors.split('">')
        directors_list = []
        for i, director in enumerate(directors):
            director = directors[i].split('</a>')[0]
            directors_list.append(director)

        directors_list.remove(directors_list[0])
        page_directors_list.append(directors_list)
    except:
        page_directors_list.append('Not found')

        
    # RELEASE DATE 
    try:
        release = movie_soup.find('h4', text='Release Date:')
        release = release.find_parent('div')
        release = str(release).split('</h4>')
        release = release[1].split('<span')[0]
        release = release.split('</div>')[0].strip()
        page_release_list.append(release)
    except:
        page_release_list.append('Not found')
    

    # FILMING LOCATION
    try:
        location = movie_soup.find('h4', text='Filming Locations:')
        location = location.find_parent('div')
        location = str(location).split('</h4>')
        location = location[1].split('<span')[0]
        location = location.split('</div>')[0].strip()
        location = location.split('">')
        location = location[1].split('</a>')[0]
        page_location_list.append(location)
    except:
        page_location_list.append('Not found')
    
    # ALSO KNOWN AS
    # helpful feature, based on title changes between adaptations
    try:
        aka = movie_soup.find('h4', text='Also Known As:')
        aka = aka.find_parent('div')
        aka = str(aka).split('</h4>')
        aka = aka[1].split('<span')[0]
        aka = aka.split('</div>')[0].strip()
        page_aka_list.append(aka)
    except:
        page_aka_list.append('Not found')
    
    # OSCAR NOMINATION
    # this number represents number of Oscar nominations
    try:
        awards = movie_soup
        awards = movie_soup.find('span', class_='awards-blurb')
        awards = str(awards).split('Nominated for')
        awards = awards[1].split('\n')
        awards = awards[1].strip()
        page_awards_list.append(awards)
    except:
        page_awards_list.append('None')
    
    
    # GENRE
    # returns a list of genres (as multiple films have multiple genres)
    genre = movie_soup.find_all('script', type="application/ld+json")

    genre = str(genre).split("genre")
    genre = genre[1].split("  ]")
    genre = genre[0].split("\n")
    genre.remove(genre[0])
    genre.remove(genre[(len(genre)-1)])
    genre_list = []
    for entry in genre:
        entry = entry.strip()
        entry = entry.replace('\"', '')
        entry = entry.replace(',', '')
        genre_list.append(entry)

    page_genres_list.append(genre_list)
    
    
    # BUDGET
    try:
        budget_value = movie_soup
        budget_value = movie_soup.find('h4', text='Budget:')
        budget_value = budget_value.find_parent('div')
        budget_value = str(budget_value).split('</h4>')
        budget_value = budget_value[1].split('<span')[0]
        page_budget_list.append(budget_value)
    except:
        page_budget_list.append('Not found')
    

    # GROSS USA - aka domestic gross
    try:
        grossUSA = movie_soup.find('h4', text='Gross USA:')
        grossUSA = grossUSA.find_parent('div')
        grossUSA = str(grossUSA).split('</h4>')
        grossUSA = grossUSA[1].split('<span')[0]
        grossUSA = grossUSA.split('</div>')[0].strip()
        page_grossUSA_list.append(grossUSA)
    except:
        page_grossUSA_list.append('Not found')
    
    
    # WORLDWIDE GROSS 
    try:
        worldwide = movie_soup.find('h4', text='Cumulative Worldwide Gross:')
        worldwide = worldwide.find_parent('div')
        worldwide = str(worldwide).split('</h4>')
        worldwide = worldwide[1].split('<span')[0]
        worldwide = worldwide.split('</div>')[0].strip()
        page_worldwide_list.append(worldwide)
    except:
        page_worldwide_list.append('Not found')
    
    
    # Find MPAA rating
    try:
        rating_value = movie_soup
        rating = movie_soup.find('div', class_='subtext').text
        rating = rating.split('\n')
        rating = rating[1].strip()
        page_rating_list.append(rating)
    except:
        page_rating_list.append("Not found")

# %% [markdown]
# ## Within the function above is a function to scrape URL's from these master pages of 50 URL's or more

# %%
def scrape_urls_from_50_per_page(url):
    # retries larger page, listing 50 movies at a time
    page = requests.get(url)
    page_soup = BeautifulSoup(page.text, 'html5lib')


    # Create list for storage of URL and title coorelated
    title_list = []
    url_list = []

    # Function to extract URL (and title) from this page
    for i in np.arange(0,50):
        values = page_soup.find_all('h3', class_="lister-item-header")[i]
        values = str(values).split('a href=')
        info = values[1].split('>')
        url=info[0]
        url = url.strip('"')
        title=(info[1].split('<'))[0]
        url_list.append(url)
        title_list.append(title)
        
    # for url in page_url_list
        
    page_url_list = []

    for url in url_list:
        base_url = 'https://www.imdb.com/'
        full_url = base_url+url
        # movie_page = requests.get(full_url)
        page_url_list.append(full_url)
        
    return page_url_list

# %%
# INDIVIDUAL PAGE - SCRAPE URL EXTENSION

values = page_soup.find_all('h3', class_="lister-item-header")[1]
values = str(values).split('a href=')
info = values[1].split('>')
url=info[0]
url = url.strip('"')
title=(info[1].split('<'))[0]

url
# Out:
# '/title/tt8503618/'

# %% [markdown]
# ## This data led to two scraped data sets, which led to the second notebook, 2_Table_Merge_and_Feature_Engineering

# %%
import pandas as pd

musical_movies = pd.read_csv('ORIGINAL_musical_movies_10520.csv')
musical_movies['new_scrape'] = musical_movies['FILM_mpaa_rating'].isnull()
new_scrape = musical_movies[musical_movies['new_scrape'] == True]
tconst = new_scrape['FILM_tconst']

# %%
tconst_list = tconst

import requests as requests
import re
from bs4 import BeautifulSoup
import numpy as np
from scrape_urls_from_50_movie_list_page import scrape_urls_from_50_movie_list_page
import pandas as pd

url_list = []

for page in tconst_list:
    url = 'https://www.imdb.com/title/' + page
    url_list.append(url)
# ...etc
page_release_list = []

    # requests soup for each individual page in ind_master_url_list, and extracts all needed features
for movie_page in url_list:
    movie = requests.get(movie_page)
    movie_soup = BeautifulSoup(movie.text, 'html5lib')

        # RELEASE DATE 
    try:
        release = movie_soup.find('h4', text='Release Date:')
        release = release.find_parent('div')
        release = str(release).split('</h4>')
        release = release[1].split('<span')[0]
        release = release.split('</div>')[0].strip()
        page_release_list.append(release)
    except:
        page_release_list.append('Not found')
        
page_release_list
# Out:
# ['18 October 1961 (USA)',
#  '10 December 2021 (USA)',
#  '25 November 1992 (USA)',
#  'Not found',
#  '25 December 2000 (UK)',
#  '25 December 1952 (Denmark)',
#  '1967 (USA)',
#  '24 December 1974 (UK)',
#  '6 February 2020 (Egypt)',
#  '1963 (Australia)',
#  '26 December 1951 (UK)',
#  '26 December 2001 (UK)',
#  '26 December 1957 (UK)',
#  '31 December 1960 (UK)',
#  '24 May 2019 (USA)',
#  '25 December 1971 (UK)',
#  '2017 (UK)',
#  '4 July 2020 (USA)',
#  '23 December 1927 (USA)',
#  '24 January 2003 (USA)',
#  '29 April 2011 (Germany)',
#  'Not found',
#  'Not found',
#  '2 May 2019 (USA)',
#  '18 June 1982 (USA)',
#  '19 December 2014 (USA)',
#  'Not found',
#  '15 November 2015 (USA)',
#  'Not found',
#  '28 December 1914 (USA)',
#  '4 March 1950 (USA)',
#  '1963 (UK)',
#  '22 February 1965 (USA)',
#  'May 1977 (USA)',
#  '2 November 1997 (USA)',
#  '31 March 1957 (USA)',
#  '1 July 1937 (France)',
#  '17 December 2001 (USA)',
#  '2 January 2000 (UK)',
#  '25 December 1970 (UK)',
#  '1974 (Philippines)',
#  '2018 (USA)',
#  '5 February 2021 (USA)',
#  '23 December 1962 (Australia)',
#  '12 May 1965 (Australia)',
#  '13 March 2015 (USA)',
#  '26 December 1958 (UK)',
#  '26 December 1950 (UK)',
#  'Not found',
#  '2 May 2013 (UK)',
#  '19 January 1937 (UK)',
#  '1995 (Italy)',
#  'Not found',
#  '18 April 2016 (USA)',
#  '26 December 1961 (UK)',
#  '1 January 2009 (Armenia)',
#  '25 December 1969 (UK)',
#  '2018 (India)',
#  'Not found',
#  '28 December 1914 (USA)',
#  '4 March 1950 (USA)',
#  '1963 (UK)',
#  '22 February 1965 (USA)',
#  'May 1977 (USA)',
#  '2 November 1997 (USA)',
#  '31 March 1957 (USA)',
#  '1 July 1937 (France)',
#  '17 December 2001 (USA)',
#  '2 January 2000 (UK)',
#  '25 December 1970 (UK)',
#  '1974 (Philippines)',
#  '2018 (USA)',
#  '5 February 2021 (USA)',
#  '23 December 1962 (Australia)',
#  '12 May 1965 (Australia)',
#  '13 March 2015 (USA)',
#  '26 December 1958 (UK)',
#  '26 December 1950 (UK)',
#  'Not found',
#  '2 May 2013 (UK)',
#  '19 January 1937 (UK)',
#  '1995 (Italy)',
#  'Not found',
#  '18 April 2016 (USA)',
#  '26 December 1961 (UK)',
#  '1 January 2009 (Armenia)',
#  '25 December 1969 (UK)',
#  '2018 (India)',
#  'Not found',
#  '28 December 1914 (USA)',
#  '4 March 1950 (USA)',
#  '1963 (UK)',
#  '22 February 1965 (USA)',
#  'May 1977 (USA)',
#  '2 November 1997 (USA)',
#  '31 March 1957 (USA)',
#  '1 July 1937 (France)',
#  '17 December 2001 (USA)',
#  '2 January 2000 (UK)',
#  '25 December 1970 (UK)',
#  '1974 (Philippines)',
#  '2018 (USA)',
#  '5 February 2021 (USA)',
#  '23 December 1962 (Australia)',
#  '12 May 1965 (Australia)',
#  '13 March 2015 (USA)',
#  '26 December 1958 (UK)',
#  '26 December 1950 (UK)',
#  'Not found',
#  '2 May 2013 (UK)',
#  '19 January 1937 (UK)',
#  '1995 (Italy)',
#  'Not found',
#  '18 April 2016 (USA)',
#  '26 December 1961 (UK)',
#  '1 January 2009 (Armenia)',
#  '25 December 1969 (UK)',
#  '2018 (India)',
#  'Not found',
#  '28 December 1914 (USA)',
#  '4 March 1950 (USA)',
#  '1963 (UK)',
#  '22 February 1965 (USA)',
#  'May 1977 (USA)',
#  '2 November 1997 (USA)',
#  '31 March 1957 (USA)',
#  '1 July 1937 (France)',
#  '17 December 2001 (USA)',
#  '2 January 2000 (UK)',
#  '25 December 1970 (UK)',
#  '1974 (Philippines)',
#  '2018 (USA)',
#  '5 February 2021 (USA)',
#  '23 December 1962 (Australia)',
#  '12 May 1965 (Australia)',
#  '13 March 2015 (USA)',
#  '26 December 1958 (UK)',
#  '26 December 1950 (UK)',
#  'Not found',
#  '2 May 2013 (UK)',
#  '19 January 1937 (UK)',
#  '1995 (Italy)',
#  'Not found',
#  '18 April 2016 (USA)',
#  '26 December 1961 (UK)',
#  '1 January 2009 (Armenia)',
#  '25 December 1969 (UK)',
#  '2018 (India)',
#  'Not found',
#  '28 December 1914 (USA)',
#  '4 March 1950 (USA)',
#  '1963 (UK)',
#  '22 February 1965 (USA)',
#  'May 1977 (USA)',
#  '2 November 1997 (USA)',
#  '31 March 1957 (USA)',
#  '1 July 1937 (France)',
#  '17 December 2001 (USA)',
#  '2 January 2000 (UK)',
#  '25 December 1970 (UK)',
#  '1974 (Philippines)',
#  '2018 (USA)',
#  '5 February 2021 (USA)',
#  '23 December 1962 (Australia)',
#  '12 May 1965 (Australia)',
#  '13 March 2015 (USA)',
#  '26 December 1958 (UK)',
#  '26 December 1950 (UK)',
#  'Not found',
#  '2 May 2013 (UK)',
#  '19 January 1937 (UK)',
#  '1995 (Italy)',
#  'Not found',
#  '18 April 2016 (USA)',
#  '26 December 1961 (UK)',
#  '1 January 2009 (Armenia)',
#  '25 December 1969 (UK)',
#  '2018 (India)',
#  'Not found',
#  '25 December 1964 (USA)',
#  'Not found',
#  '7 January 2019 (Romania)',
#  'Not found',
#  '26 March 1927 (USA)',
#  '23 March 1953 (Spain)',
#  '13 February 1972 (USA)',
#  '1993 (UK)',
#  '30 June 1962 (France)',
#  'Not found',
#  '9 January 2019 (India)',
#  '26 March 1927 (USA)',
#  '23 March 1953 (Spain)',
#  '13 February 1972 (USA)',
#  '1993 (UK)',
#  '30 June 1962 (France)',
#  'Not found',
#  '9 January 2019 (India)',
#  '20 December 1985 (USA)',
#  '1 August 2016 (USA)',
#  '29 June 1956 (USA)',
#  '19 March 1999 (USA)',
#  '29 November 2018 (USA)',
#  '23 November 1956 (Austria)',
#  '22 November 2003 (USA)',
#  '7 August 2013 (USA)',
#  '11 March 1933 (USA)',
#  'August 1986 (Japan)',
#  '30 March 1997 (Portugal)',
#  '17 November 2017 (USA)',
#  '10 February 1933 (USA)',
#  '30 August 1945 (USA)',
#  '9 March 1962 (USA)',
#  '1976 (USA)',
#  '6 October 1954 (USA)',
#  '26 May 1982 (France)',
#  '29 September 1996 (USA)',
#  '1 July 1999 (Australia)',
#  '21 September 1951 (France)',
#  '26 February 1917 (USA)',
#  '15 October 1993 (Canada)',
#  '17 August 1991 (USA)',
#  '15 May 2019 (France)',
#  '30 August 2013 (USA)',
#  '1990 (Germany)',
#  'Not found',
#  '24 January 1936 (USA)',
#  'April 1956 (USA)',
#  '4 December 2012 (Canada)',
#  '28 April 1962 (Norway)',
#  'Not found',
#  '1 May 1939 (USA)',
#  '15 March 1967 (USA)',
#  '2 January 1983 (Canada)',
#  '18 August 1983 (Australia)',
#  'Not found',
#  '30 December 1987 (UK)',
#  '1992 (UK)',
#  'Not found',
#  '1987 (Australia)',
#  'Not found',
#  '28 December 1973 (UK)',
#  '2 July 2019 (UK)',
#  '20 November 2011 (Australia)',
#  '24 December 1962 (UK)',
#  '3 July 1930 (USA)',
#  '15 June 1938 (USA)',
#  '10 February 2006 (India)',
#  '7 December 1996 (USA)',
#  '8 December 2010 (France)',
#  '6 June 2014 (India)',
#  'Not found',
#  '28 May 2016 (USA)',
#  '19 June 2017 (China)',
#  '1 February 2019 (USA)',
#  '21 May 2018 (USA)',
#  '21 July 1974 (Australia)',
#  '29 April 1938 (USA)',
#  '22 October 2004 (Sweden)',
#  '19 June 2002 (UK)',
#  '27 December 1940 (USA)',
#  '23 May 1984 (USA)',
#  '3 September 2005 (Hungary)',
#  '26 February 2006 (USA)',
#  'Not found',
#  'Not found',
#  'Not found',
#  '9 August 1940 (USA)',
#  'August 1996 (USA)',
#  '6 January 1980 (UK)',
#  '1986 (Australia)',
#  '2 January 1939 (UK)',
#  '15 December 1957 (USA)',
#  '8 April 1964 (Canada)',
#  '1986 (Canada)',
#  '28 September 1966 (Australia)',
#  '10 March 2012 (Canada)',
#  '4 April 2014 (USA)',
#  '16 September 2014 (USA)',
#  '5 January 2018 (USA)',
#  '25 October 2018 (UK)',
#  '2017 (USA)',
#  '22 October 1981 (South Africa)',
#  'Not found',
#  'Not found',
#  '2010 (Hungary)',
#  '25 November 2015 (USA)',
#  '23 September 2015 (France)',
#  'Not found',
#  'Not found',
#  'Not found',
#  '16 December 1938 (USA)',
#  '17 December 1984 (USA)',
#  '24 December 1977 (UK)',
#  '5 December 1999 (USA)',
#  '25 December 1947 (USA)',
#  '20 November 2000 (UK)',
#  '8 December 1994 (USA)',
#  '27 December 1950 (UK)',
#  '21 December 1981 (USA)',
#  '22 December 1943 (USA)',
#  'Not found',
#  '28 November 2004 (USA)',
#  '13 December 1970 (USA)',
#  '22 December 1982 (Australia)',
#  '2020 (UK)',
#  '31 December 2019 (UK)',
#  '6 November 2009 (USA)',
#  '2 December 2019 (USA)',
#  'Not found',
#  '1979 (USA)',
#  '19 November 2013 (USA)',
#  '5 December 2009 (USA)',
#  '16 December 2018 (UK)',
#  '20 November 2015 (USA)',
#  'Not found',
#  '24 December 1962 (UK)',
#  'Not found',
#  '1 November 2017 (UK)',
#  '11 December 2018 (Ireland)',
#  '2021 (UK)',
#  'Not found',
#  '23 November 2018 (USA)',
#  '1 December 2018 (USA)',
#  '16 December 1938 (USA)',
#  '17 December 1984 (USA)',
#  '24 December 1977 (UK)',
#  '5 December 1999 (USA)',
#  '25 December 1947 (USA)',
#  '20 November 2000 (UK)',
#  '8 December 1994 (USA)',
#  '27 December 1950 (UK)',
#  '21 December 1981 (USA)',
#  '22 December 1943 (USA)',
#  'Not found',
#  '28 November 2004 (USA)',
#  '13 December 1970 (USA)',
#  '22 December 1982 (Australia)',
#  '2020 (UK)',
#  '31 December 2019 (UK)',
#  '6 November 2009 (USA)',
#  '2 December 2019 (USA)',
#  'Not found',
#  '1979 (USA)',
#  '19 November 2013 (USA)',
#  '5 December 2009 (USA)',
#  '16 December 2018 (UK)',
#  '20 November 2015 (USA)',
#  'Not found',
#  '24 December 1962 (UK)',
#  'Not found',
#  '1 November 2017 (UK)',
#  '11 December 2018 (Ireland)',
#  '2021 (UK)',
#  'Not found',
#  '23 November 2018 (USA)',
#  '1 December 2018 (USA)',
#  '6 November 1985 (USA)',
#  '9 February 1973 (USA)',
#  '24 July 2015 (USA)',
#  '21 May 1974 (UK)',
#  '2009 (Australia)',
#  '4 October 2010 (Australia)',
#  '17 February 1960 (Australia)',
#  '21 May 1974 (UK)',
#  '2009 (Australia)',
#  '4 October 2010 (Australia)',
#  '17 February 1960 (Australia)',
#  '24 December 1917 (USA)',
#  '10 February 1924 (USA)',
#  '26 October 1945 (USA)',
#  '27 April 1984 (USA)',
#  'Not found',
#  '12 April 1999 (USA)',
#  '21 July 1988 (Philippines)',
#  '14 June 1970 (Philippines)',
#  '31 January 2010 (Canada)',
#  '1 April 2007 (USA)',
#  'Not found',
#  '24 July 2015 (USA)',
#  '2008 (France)',
#  '18 May 2014 (USA)',
#  'Not found',
#  'Not found',
#  'Not found',
#  '19 October 2012 (USA)',
#  '10 July 1999 (USA)',
#  'Not found',
#  'Not found',
#  'Not found',
#  '20 September 1956 (Argentina)',
#  '22 August 1982 (USA)',
#  '18 June 1967 (Philippines)',
#  'September 2014 (USA)',
#  'Not found',
#  '21 July 2017 (India)',
#  '2 February 1910 (USA)',
#  '15 April 1911 (USA)',
#  '22 September 1913 (UK)',
#  '8 November 1921 (USA)',
#  '11 June 1948 (Australia)',
#  'Not found',
#  '4 December 1955 (Sweden)',
#  '23 September 1964 (USA)',
#  'Not found',
#  '9 April 1970 (UK)',
#  '7 November 1970 (USA)',
#  'Not found',
#  '21 November 1976 (UK)',
#  'Not found',
#  '18 January 1991 (USA)',
#  '25 December 1996 (USA)',
#  'Not found',
#  '23 June 2000 (USA)',
#  'Not found',
#  '26 April 1953 (USA)',
#  'Not found',
#  '10 December 2000 (USA)',
#  '21 March 1990 (France)',
#  'Not found',
#  'Not found',
#  '2 January 1992 (Finland)',
#  'Not found',
#  '23 June 1979 (France)',
#  '22 August 1983 (Hungary)',
#  '1964 (Argentina)',
#  '25 January 2007 (Netherlands)',
#  '19 November 2005 (Ireland)',
#  '20 September 1962 (Belgium)',
#  '2007 (UK)',
#  'Not found',
#  '2019 (Netherlands)',
#  '10 November 2017 (Sweden)',
#  'Not found',
#  '15 September 1980 (Yugoslavia)',
#  '1 May 2020 (Germany)',
#  'Not found',
#  '23 April 2010 (USA)',
#  '7 October 1970 (Finland)',
#  '25 August 1993 (Netherlands)',
#  '17 June 1959 (Australia)',
#  '10 January 2014 (USA)',
#  'Not found',
#  'Not found',
#  '10 October 1985 (Finland)',
#  'Not found',
#  'Not found',
#  '23 March 2015 (UK)',
#  '28 April 2017 (UK)',
#  'Not found',
#  'Not found',
#  '24 April 2016 (USA)',
#  '9 November 2017 (Georgia)',
#  'Not found',
#  '16 December 2013 (France)',
#  'Not found',
#  '31 March 1983 (Hungary)',
#  '31 March 2018 (UK)',
#  'Not found',
#  '24 July 1938 (UK)',
#  'Not found',
#  '13 November 1953 (West Germany)',
#  '4 June 1953 (USA)',
#  '23 April 1964 (UK)',
#  '21 February 1970 (Japan)',
#  '14 February 1979 (USA)',
#  'Not found',
#  '17 November 1966 (Canada)',
#  '1953 (USA)',
#  '2007 (USA)',
#  '31 October 2010 (USA)',
#  '1 April 2011 (UK)',
#  '24 June 2012 (UK)',
#  '22 November 1988 (West Germany)',
#  'Not found',
#  '4 June 1916 (USA)',
#  '31 December 1915 (France)',
#  'Not found',
#  '10 May 1949 (Mexico)',
#  '20 February 1949 (UK)',
#  '28 November 1954 (USA)',
#  '20 November 1960 (USA)',
#  'Not found',
#  '5 November 1983 (UK)',
#  'Not found',
#  '18 May 1987 (France)',
#  '16 January 1987 (Finland)',
#  '16 May 1997 (UK)',
#  'Not found',
#  '15 January 1998 (UK)',
#  'Not found',
#  'Not found',
#  '16 March 1983 (Hungary)',
#  '20 October 1959 (France)',
#  '1965 (Australia)',
#  '22 January 1961 (Canada)',
#  '26 November 2002 (USA)',
#  '22 February 2003 (USA)',
#  '18 December 1971 (West Germany)',
#  '1993 (Finland)',
#  '21 September 2006 (Australia)',
#  '10 December 2004 (Sweden)',
#  '10 September 1974 (West Germany)',
#  '17 November 1968 (USA)',
#  'Not found',
#  'Not found',
#  'November 1960 (Italy)',
#  '20 February 1975 (Italy)',
#  '2020 (UK)',
#  '20 October 2016 (Spain)',
#  '1981 (Czechoslovakia)',
#  '20 May 2015 (UK)',
#  'Not found',
#  '19 May 2006 (USA)',
#  '17 November 2009 (USA)',
#  '1960 (Australia)',
#  '13 June 2011 (USA)',
#  '2004 (USA)',
#  '13 March 1989 (Portugal)',
#  'January 1976 (Italy)',
#  '1 January 2013 (USA)',
#  'April 2009 (France)',
#  '2006 (Italy)',
#  '11 December 2015 (USA)',
#  'Not found',
#  '25 June 2014 (UK)',
#  '13 March 2018 (UK)',
#  'Not found',
#  'Not found',
#  '25 September 1980 (South Africa)',
#  '18 March 2017 (USA)',
#  '2018 (USA)',
#  'Not found',
#  '13 October 1963 (West Germany)',
#  '2011 (UK)',
#  'February 1914 (USA)',
#  'July 1916 (UK)',
#  '1 July 1947 (UK)',
#  '7 October 1973 (USA)',
#  '17 December 1980 (UK)',
#  'Not found',
#  'Not found',
#  '18 February 2005 (USA)',
#  '4 August 2016 (UK)',
#  '21 May 2016 (UK)',
#  '1 January 2009 (USA)',
#  '1961 (Australia)',
#  'Not found',
#  '12 April 1987 (South Africa)',
#  '22 October 1916 (USA)',
#  '19 October 1916 (USA)',
#  '3 September 1936 (USA)',
#  '25 November 1954 (Italy)',
#  '5 October 1966 (USA)',
#  '8 October 1968 (USA)',
#  'Not found',
#  '22 September 1976 (UK)',
#  '1984 (UK)',
#  'Not found',
#  '14 November 1981 (USA)',
#  '22 July 2014 (USA)',
#  '1 April 2014 (Ireland)',
#  '25 December 2007 (UK)',
#  '25 December 2014 (Italy)',
#  '15 May 2018 (UK)',
#  '3 March 2018 (Canada)',
#  'Not found',
#  'Not found',
#  '2013 (UK)',
#  '17 December 1916 (USA)',
#  'July 1970 (UK)',
#  'Not found',
#  '18 October 1982 (USA)',
#  '26 January 1984 (USA)',
#  '3 April 2002 (France)',
#  'Not found',
#  'Not found',
#  'Not found',
#  '25 December 2008 (UK)',
#  '2017 (USA)',
#  '25 February 2015 (USA)',
#  '1 September 2018 (UK)',
#  '28 September 2018 (USA)',
#  'December 2017 (Russia)',
#  'Not found',
#  '30 October 1935 (USA)',
#  '24 July 1946 (UK)',
#  'Not found',
#  '17 April 1967 (USA)',
#  '9 February 1969 (USA)',
#  '13 December 1981 (UK)',
#  '1982 (USA)',
#  'February 1985 (UK)',
#  '29 November 1996 (UK)',
#  '14 May 1999 (USA)',
#  'Not found',
#  '1999 (UK)',
#  'Not found',
#  '17 October 2019 (USA)',
#  '7 November 2019 (Australia)',
#  '23 April 2020 (UK)',
#  '4 July 2015 (France)',
#  '29 November 2010 (USA)',
#  '1959 (USA)',
#  '28 November 2006 (Slovenia)',
#  '22 June 2015 (USA)',
#  'Not found',
#  '30 May 2016 (UK)',
#  '13 July 2018 (USA)',
#  '23 April 2016 (UK)',
#  '2017 (USA)',
#  'Not found',
#  '28 October 1982 (South Africa)',
#  '10 May 2009 (UK)',
#  '23 March 1919 (USA)',
#  'Not found',
#  '28 December 1949 (USA)',
#  '13 February 1961 (USA)',
#  '27 November 2019 (Philippines)',
#  'Not found',
#  'Not found',
#  'Not found',
#  '11 March 1917 (USA)',
#  '25 December 1935 (USA)',
#  '4 August 1958 (USA)',
#  '2 December 1980 (USA)',
#  '8 June 1984 (Australia)',
#  '2 October 1958 (UK)',
#  'Not found',
#  '18 December 2020 (USA)',
#  'Not found',
#  '21 September 1962 (UK)',
#  '1979 (Bangladesh)',
#  'Not found',
#  'Not found',
#  '17 July 1938 (UK)',
#  'Not found',
#  '11 September 2010 (USA)',
#  '1963 (UK)',
#  '1961 (Australia)',
#  '25 March 2001 (UK)',
#  '14 November 1948 (UK)',
#  'Not found',
#  'Not found',
#  '20 December 1982 (USA)',
#  '13 March 2015 (USA)',
#  '29 November 1937 (UK)',
#  'Not found',
#  '1 November 1974 (West Germany)',
#  '14 December 1914 (USA)',
#  '4 May 1967 (USA)',
#  'Not found',
#  '27 November 1996 (USA)',
#  'July 2012 (South Korea)',
#  '4 December 2014 (UK)',
#  '2010 (UK)',
#  '27 June 1914 (USA)',
#  '6 November 1921 (USA)',
#  '15 August 1934 (USA)',
#  '7 April 1944 (USA)',
#  '24 March 1971 (USA)',
#  '12 April 1996 (USA)',
#  '19 October 1997 (USA)',
#  '27 April 1961 (USA)',
#  'Not found',
#  '6 May 1910 (USA)',
#  '22 January 1958 (Netherlands)',
#  '22 April 2011 (USA)',
#  '29 September 1946 (UK)',
#  '26 September 1948 (UK)',
#  '31 January 2019 (China)',
#  '19 October 1914 (USA)',
#  '23 April 1993 (UK)',
#  '21 December 1914 (USA)',
#  '4 February 1924 (UK)',
#  '19 May 1937 (UK)',
#  '17 May 1955 (USA)',
#  'Not found',
#  '5 February 1974 (USA)',
#  '2012 (Japan)',
#  '16 August 1915 (USA)',
#  '2 August 1915 (USA)',
#  '28 May 2012 (USA)',
#  '1 January 2015 (USA)',
#  '4 May 1919 (USA)',
#  '6 April 1964 (USA)',
#  '12 October 1917 (USA)',
#  '22 October 1999 (USA)',
#  '19 January 2006 (Germany)',
#  '20 March 2006 (UK)',
#  'Not found',
#  '2006 (USA)',
#  '11 June 1917 (USA)',
#  '9 June 1918 (USA)',
#  '12 February 1922 (USA)',
#  '10 April 1973 (Netherlands)',
#  '17 May 1973 (France)',
#  '15 November 1959 (USA)',
#  'Not found',
#  '4 November 1952 (UK)',
#  '2012 (UK)',
#  '19 January 1918 (USA)',
#  '1 August 1927 (USA)',
#  '27 September 1991 (Netherlands)',
#  '1 December 2001 (Greece)',
#  'Not found',
#  '4 November 1917 (USA)',
#  '7 February 1935 (USA)',
#  '9 November 1982 (USA)',
#  'Not found',
#  'Not found',
#  'Not found',
#  '13 May 1918 (USA)',
#  '9 April 1930 (USA)',
#  'Not found',
#  '11 November 1937 (UK)',
#  'Not found',
#  '19 March 1954 (UK)',
#  '2 February 2018 (UK)',
#  '5 January 1919 (USA)',
#  '24 November 1933 (USA)',
#  'April 1949 (USA)',
#  '25 December 1994 (USA)',
#  '16 October 1958 (USA)',
#  'July 1917 (UK)',
#  '29 January 1946 (USA)',
#  '22 December 1939 (USA)',
#  '25 December 2019 (USA)',
#  'Not found',
#  '28 September 2018 (USA)',
#  '8 July 1918 (USA)',
#  'Not found',
#  '27 May 1984 (USA)',
#  '28 August 1985 (France)',
#  '23 October 1987 (USA)',
#  'February 1964 (USA)',
#  '25 December 2000 (Denmark)',
#  '19 September 2001 (France)',
#  '3 October 1978 (UK)',
#  '2021 (USA)',
#  'June 2021 (France)',
#  '2009 (USA)',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  '1 May 2001 (Ireland)',
#  'September 2012 (Germany)',
#  '23 February 1956 (UK)',
#  'Not found',
#  '1 June 2016 (New Zealand)',
#  'Not found',
#  'Not found',
#  'Not found',
#  '12 October 2018 (Austria)',
#  'Not found',
#  '4 June 2019 (USA)',
#  'Not found',
#  'Not found',
#  '10 August 1918 (USA)',
#  '16 April 1953 (Argentina)',
#  '1 January 1923 (USA)',
#  '16 February 1975 (West Germany)',
#  '30 May 1992 (UK)',
#  '7 August 1981 (Philippines)',
#  '11 June 1971 (West Germany)',
#  '1952 (Philippines)',
#  '19 July 2019 (Germany)',
#  '1 May 1968 (Australia)',
#  '1990 (Germany)',
#  '2008 (UK)',
#  'Not found',
#  '27 March 2012 (USA)',
#  'June 2014 (Iceland)',
#  '26 September 1957 (UK)',
#  '20 October 1959 (West Germany)',
#  'January 1920 (Germany)',
#  '28 April 1985 (Hungary)',
#  '6 October 1919 (USA)',
#  '31 December 1970 (UK)',
#  '25 June 2004 (Australia)',
#  '4 November 2011 (India)',
#  '4 December 2009 (USA)',
#  '13 January 2012 (Nepal)',
#  'Not found',
#  '12 January 1919 (USA)',
#  '22 July 1949 (Brazil)',
#  '30 November 1987 (USA)',
#  '13 August 1993 (USA)',
#  'Not found',
#  '7 August 2020 (USA)',
#  '1 May 2016 (USA)',
#  'Not found',
#  '17 September 2020 (Australia)',
#  '22 September 1920 (USA)',
#  'Not found',
#  '23 September 1951 (USA)',
#  '26 April 1955 (UK)',
#  '10 September 1921 (USA)',
#  '20 August 1927 (USA)',
#  '3 November 1989 (USA)',
#  'Not found',
#  'Not found',
#  '28 October 2014 (USA)',
#  '2003 (USA)',
#  '20 February 2020 (Kuwait)',
#  '27 November 1921 (USA)',
#  'Not found',
#  '2 December 2016 (USA)',
#  '14 October 2010 (India)',
#  '10 May 2012 (Netherlands)',
#  '2013 (USA)',
#  'Not found',
#  'March 1920 (USA)',
#  'Not found',
#  'April 1922 (USA)',
#  '12 February 1937 (USA)',
#  '15 July 1982 (Australia)',
#  '2 February 2001 (USA)',
#  '18 July 2014 (USA)',
#  '12 October 2018 (USA)',
#  '6 March 1922 (USA)',
#  '15 September 1972 (West Germany)',
#  '9 December 1918 (USA)',
#  '27 October 2017 (USA)',
#  '2019 (USA)',
#  '25 November 1923 (USA)',
#  '21 February 1930 (USA)',
#  '22 December 1930 (Germany)',
#  'Not found',
#  '16 September 1960 (Italy)',
#  '8 May 1964 (Finland)',
#  '1982 (Greece)',
#  '23 July 1946 (UK)',
#  '4 January 1963 (UK)',
#  '22 October 1923 (USA)',
#  '6 April 1929 (USA)',
#  '21 December 1956 (USA)',
#  'March 1975 (USA)',
#  'Not found',
#  '22 September 1925 (USA)',
#  '15 August 1967 (USA)',
#  '5 December 2002 (Spain)',
#  '11 August 2006 (USA)',
#  '4 September 1939 (UK)',
#  '14 April 2009 (United Arab Emirates)',
#  'Not found',
#  '26 October 2017 (UK)',
#  '5 October 1972 (USA)',
#  '28 April 2017 (USA)',
#  '12 September 1948 (UK)',
#  'Not found',
#  'Not found',
#  '20 August 2016 (USA)',
#  'Not found',
#  '20 August 1959 (USA)',
#  '20 November 1955 (USA)',
#  '26 July 1949 (UK)',
#  '10 May 1926 (USA)',
#  '13 December 1956 (USA)',
#  '24 October 1982 (USA)',
#  '21 November 1997 (USA)',
#  '10 October 1926 (USA)',
#  '28 August 1953 (USA)',
#  'Not found',
#  '1 September 1927 (USA)',
#  '25 December 1981 (USA)',
#  '11 May 1929 (USA)',
#  '3 December 1974 (USA)',
#  '13 November 1978 (USA)',
#  '20 February 1983 (USA)',
#  '25 July 1932 (UK)',
#  'Not found',
#  '1 August 2003 (USA)',
#  '3 April 2015 (USA)',
#  '2 November 2014 (UK)',
#  '16 December 2016 (Nigeria)',
#  'October 2017 (Germany)',
#  'Not found',
#  '15 September 1929 (USA)',
#  '7 December 1942 (UK)',
#  'November 1973 (USA)',
#  '22 May 1938 (UK)',
#  'Not found',
#  '7 April 2011 (France)',
#  'November 2011 (France)',
#  '6 October 1929 (USA)',
#  '19 December 1951 (France)',
#  '11 January 1985 (USA)',
#  '2002 (USA)',
#  'Not found',
#  '2 August 2018 (Bolivia)',
#  '10 January 2020 (USA)',
#  '24 May 1929 (USA)',
#  '15 May 1948 (USA)',
#  '5 April 1998 (USA)',
#  '26 January 1930 (USA)',
#  '22 September 1930 (UK)',
#  '1 February 1960 (USA)',
#  '21 October 1938 (UK)',
#  '1980 (UK)',
#  '20 April 1930 (USA)',
#  'Not found',
#  '29 December 1981 (UK)',
#  'January 2015 (UK)',
#  '14 February 1931 (USA)',
#  '16 June 1958 (UK)',
#  '8 February 1974 (USA)',
#  '20 July 1979 (USA)',
#  '13 November 1992 (USA)',
#  '1994 (USA)',
#  '11 February 2007 (USA)',
#  '30 September 2019 (USA)',
#  '7 January 2020 (USA)',
#  '19 May 1999 (India)',
#  '24 November 1972 (West Germany)',
#  'Not found',
#  '4 April 1931 (USA)',
#  '20 December 1974 (Canada)',
#  '15 August 1948 (UK)',
#  '11 November 1945 (USA)',
#  '31 January 1970 (USA)',
#  '12 December 1931 (USA)',
#  '12 August 1939 (UK)',
#  '28 December 1976 (UK)',
#  '4 October 1931 (USA)',
#  '17 January 1998 (USA)',
#  'Not found',
#  'Not found',
#  '2021 (USA)',
#  'Not found',
#  'Not found',
#  '1 July 1932 (USA)',
#  '11 September 1932 (USA)',
#  '1987 (Finland)',
#  'Not found',
#  '8 April 2016 (Norway)',
#  'Not found',
#  '29 December 1933 (USA)',
#  '12 January 1934 (USA)',
#  '11 December 1989 (USA)',
#  '7 July 1933 (USA)',
#  '10 March 2017 (USA)',
#  '2017 (USA)',
#  '7 April 1933 (USA)',
#  '17 December 1976 (USA)',
#  '1962 (India)',
#  '14 December 2005 (USA)',
#  'Not found',
#  '7 January 2018 (Brazil)',
#  'December 1975 (USA)',
#  '1 October 1934 (UK)',
#  'Not found',
#  '11 May 1934 (USA)',
#  '1 August 1935 (USA)',
#  '13 March 1959 (UK)',
#  'Not found',
#  '28 December 2008 (UK)',
#  '23 August 1935 (USA)',
#  '1 February 1935 (USA)',
#  '25 December 1992 (Sweden)',
#  '14 November 1937 (USA)',
#  '4 December 1988 (USA)',
#  '21 November 1936 (USA)',
#  '12 November 1937 (USA)',
#  '30 April 1937 (USA)',
#  '17 April 1964 (Canada)',
#  '26 February 1937 (Netherlands)',
#  '3 March 1939 (USA)',
#  '2 June 1968 (Sweden)',
#  '2 September 1935 (Germany)',
#  'Not found',
#  '6 February 1963 (USA)',
#  '12 July 1980 (West Germany)',
#  '8 February 1948 (UK)',
#  'Not found',
#  '4 January 1976 (Netherlands)',
#  '19 December 1982 (Hungary)',
#  '15 September 1957 (East Germany)',
#  '31 August 1956 (West Germany)',
#  '20 March 1954 (UK)',
#  'Not found',
#  '18 April 1975 (USA)',
#  '11 February 1938 (USA)',
#  '2 July 1986 (UK)',
#  '5 September 1939 (USA)',
#  '21 February 1996 (France)',
#  '25 January 1962 (Austria)',
#  'Not found',
#  '17 September 2019 (USA)',
#  '12 January 1940 (USA)',
#  '29 November 1981 (USA)',
#  '2 October 1992 (USA)',
#  '31 January 1968 (USA)',
#  '22 February 2015 (Denmark)',
#  '7 July 1939 (USA)',
#  '17 November 1957 (USA)',
#  'Not found',
#  'August 2011 (Australia)',
#  '1 September 1939 (USA)',
#  '12 September 2008 (USA)',
#  ...]

# %% [markdown]
# ### Save df as csv

# %%
df.to_csv('ORIGINAL.new_scrape_release_dates.csv')
